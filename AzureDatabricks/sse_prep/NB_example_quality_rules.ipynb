# %%
# Example data quality rules
rules = [
    {
        "name": "HighPriceCheck",      # Unique rule name
        "column": "price",             # Column to check
        "op": ">",                     # Comparison operator
        "threshold": 1000,             # Threshold value
        "severity": "WARNING"          # Optional severity
    },
    {
        "name": "NullCustomerID",
        "expr": "customer_id IS NULL", # Direct SQL expression
        "severity": "ERROR"
    }
]
